# %%
# !pip install transformers
# !pip install sentence_transformers
# !pip install --upgrade Pillow
# !pip install gtts
# !pip install moviepy 
# !pip install bing_image_downloader
# !pip install imageio==2.4.1
import nltk
nltk.download('stopwords')
nltk.download('punkt')

# %%
#Please, change this accordingly to run the pipeline (instructions in the README.txt file). 

# %cd "........"

# %%
# !rm -rf "videos"
# !rm -rf "images"
# !rm -rf "audios"
# !rm -rf "output"
# !rm -rf "Images_Product"
# !rm -rf "../data"

# !mkdir Images_Product
# !mkdir images 
# !mkdir audios
# !mkdir videos
# !mkdir output

# %%
# !cp "arial.ttf" "/usr/share/fonts/truetype"

# %%
# !python main.py #'id'
