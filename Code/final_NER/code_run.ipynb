# %% [markdown]
# insert the correct path where the code is present

# %%
cd "/content/drive/MyDrive/Applied_Data_Science_Project/Deliverables/Code/final_NER/"
# Out:
# /content/drive/.shortcut-targets-by-id/1Q-s7iBg9LuhiMq6j_d9cgyLVr2MFTUz_/Applied_Data_Science_Project/Deliverables/Code/final_NER

# %%
# !python train.py

# %%
# !python test.py
